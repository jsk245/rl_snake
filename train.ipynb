# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/MyDrive/snake
# Out:
# /content/gdrive/MyDrive/snake

# %%
# !pip install dm-haiku optax
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.1/352.1 KB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.9/154.9 KB 15.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 KB 9.4 MB/s eta 0:00:00
# ...

# %%
# !python rl_train.py
# Out:
# 2023-01-21 17:27:39.239270: E external/org_tensorflow/tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:jax._src.lib.xla_bridge:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# avg fruits: 6.225
# avg steps taken: 51.5125
# avg fruits: 5.6
# avg steps taken: 51.95
# avg fruits: 5.375
# avg steps taken: 51.3625
# avg fruits: 6.05
# avg steps taken: 62.125
# saved!
# avg fruits: 5.175
# avg steps taken: 45.75
# avg fruits: 5.9125
# avg steps taken: 48.3375
# avg fruits: 5.7625
# avg steps taken: 51.675
# avg fruits: 5.375
# avg steps taken: 53.85
# saved!
# avg fruits: 5.6
# avg steps taken: 49.2625
# avg fruits: 5.825
# avg steps taken: 54.3375
# avg fruits: 5.825
# avg steps taken: 43.8
# avg fruits: 5.8875
# avg steps taken: 45.925
# saved!
# avg fruits: 5.825
# avg steps taken: 49.05
# avg fruits: 5.3375
# avg steps taken: 39.8625
# ...
